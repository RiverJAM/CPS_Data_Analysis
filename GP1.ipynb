# %%
import pandas as pd

# %%
school_data_tofind = "Resources/Chicago_Public_Schools_-_School_Progress_Reports_SY1819.csv"
school_data_tofind2 = "Resources/Chicago_Public_Schools_-_School_Admissions_Information_SY1819.csv"
school_data_tofind3 = "Resources/employeepositionroster_12312015.csv"

# %%
school_data1 = pd.read_csv(school_data_tofind)
school_data2 = pd.read_csv(school_data_tofind2)
school_data3 = pd.read_csv(school_data_tofind3)

# %%
school_data1.head()
# Out:
#    School_ID  Short_Name                           Long_Name   School_Type  \
# 0     609869    LANGFORD  Anna R. Langford Community Academy  Neighborhood
# 1     610225    WHISTLER     John Whistler Elementary School  Neighborhood
# 2     609734     TAFT HS     William Howard Taft High School  Neighborhood
# 3     610588  RICHARDSON  Robert J. Richardson Middle School  Neighborhood
# 4     609894       DRAKE      John B Drake Elementary School  Neighborhood
#
#   Primary_Category               Address     City     State    Zip  \
# 0               ES      6010 S THROOP ST  Chicago  Illinois  60636
# 1               ES        11533 S ADA ST  Chicago  Illinois  60643
# 2               HS  6530 W BRYN MAWR AVE  Chicago  Illinois  60631
# 3               MS         6018 S KARLOV  Chicago  Illinois  60629
# 4               ES    2710 S DEARBORN ST  Chicago  Illinois  60616
#
#           Phone  ...  Attainment_SAT_Grade_11_School_Pct  \
# ...

# %%
school_data2.head()
# Out:
#    School_ID                      Short_Name  \
# 0     400059     NORTH LAWNDALE - COLLINS HS
# 1     400058  NORTH LAWNDALE - CHRISTIANA HS
# 2     610339                           STAGG
# 3     610059                           MAYER
# 4     610237                       BEETHOVEN
#
#                                   Long_Name Primary_Category  \
# 0     North Lawndale College Prep - Collins               HS
# 1  North Lawndale College Prep - Christiana               HS
# 2       Amos Alonzo Stagg Elementary School               ES
# 3                 Oscar Mayer Magnet School               ES
# 4    Ludwig Van Beethoven Elementary School               ES
#
#                  Address     City     State    Zip       Phone           Fax  \
# 0   1313 S SACRAMENTO DR  Chicago  Illinois  60623  7735426766  7.735427e+09
# 1  1615 S CHRISTIANA AVE  Chicago  Illinois  60623  7735421490  7.735421e+09
# 2       7424 S MORGAN ST  Chicago  Illinois  60621  7735353565  7.735354e+09
# ...

# %%
school_data3.head()
# Out:
#    POSITION NUMBER  UNIT NUMBER  \
# 0           111424        46181
# 1           111427        49021
# 2           111428        11675
# 3           111435        23231
# 4           111436        23131
#
#                                            UNIT NAME  FTE  ANNUAL SALARY  \
# 0                           Thomas Kelly High School  1.0       83371.08
# 1                          Northside Learning Center  1.0       69365.72
# 2  Diverse Learner Supports & Services - Related ...  1.0       61161.97
# 3                                       Telpochcalli  0.5       90658.10
# 4                                      Esmond School  1.0       91884.19
#
#   FTE ANNUAL SALARY ANNUAL BENEFIT COST  JOB CODE            JOB DESCRIPTION  \
# 0         83,371.08           28,721.00        49            Regular Teacher
# 1         69,365.72           25,604.00    500629  Special Education Teacher
# 2         61,161.97           24,589.00    984100       School Social Worker
# ...

# %%
#Total number of schools
list_of_schools = school_data["Long_Name"].unique()
#print("The Total Number of Schools is " + str(len("list_of_schools")))
len(list_of_schools)
# Out:
# 654

# %%
#Total names of schools
list_of_schools
# Out:
# array(['Anna R. Langford Community Academy',
#        'John Whistler Elementary School',
#        'William Howard Taft High School',
#        'Robert J. Richardson Middle School',
#        'John B Drake Elementary School',
#        'Mancel Talcott Elementary School',
#        'Horace Mann Elementary School', 'Patrick Henry Elementary School',
#        'Milton Brunson Math & Science Specialty ES',
#        'Frederick Funston Elementary School',
#        'Walter L Newberry Math & Science Academy ES',
#        'Daniel Webster Elementary School',
#        'Laura S Ward Elementary School', 'Peace & Education Coalition HS',
#        'Lorenz Brentano Math & Science Academy ES',
#        'Charles H Wacker Elementary School', 'CICS - ChicagoQuest North',
#        'Ralph H Metcalfe Elementary Community Academy',
#        'Ferdinand Peck Elementary School',
#        'Enrico Tonti Elementary School', 'Portage Park Elementary School',
#        'Robert Lindblom Math & Science Academy HS',
# ...

# %%
School_types = school_data1["School_Type"].unique()
School_types
# Out:
# array(['Neighborhood', 'Magnet', 'Citywide-Option', 'Charter',
#        'Selective enrollment', 'Career academy', 'Special Education',
#        'Contract', 'Regional gifted center', 'Military academy', 'Small',
#        'Classical'], dtype=object)

# %%
school_names = school_data3['UNIT NAME'].unique()
len(school_names)
# Out:
# 653

# %%
sorted(school_names)
# Out:
# ['A N Pritzker School',
#  'A Philip Randolph Magnet School',
#  'ASPIRA Business and Finance',
#  'ASPIRA Charter - Early College Campus',
#  'ASPIRA Charter-Haugan Middle School Campus',
#  'AUSL Program Support',
#  'Abraham Lincoln Elementary School',
#  'Academy for Global Citizenship',
#  'Access and Enrollment',
#  'Accountability',
#  'Accounting',
#  'Accounts Payable',
#  'Adam Clayton Powell Jr Paideia Community Academy',
#  'Adlai E Stevenson School',
#  'Agustin Lara Academy',
#  'Air Force Academy High School',
#  'Al Raby High School',
#  'Alain Locke Charter School',
#  'Albany Park Multicultural Academy Elementary School',
#  'Albert G Lane Technical High School',
#  'Albert R Sabin Magnet School',
#  'Alessandro Volta School',
#  'Alex Haley School',
#  'Alexander Graham Bell School',
#  'Alexander Graham School',
#  'Alexander Hamilton School',
#  'Alfred Nobel Elementary School',
#  'Alice L Barnard Computer Math & Science Center',
#  'Ambrose Plamondon School',
# ...

# %%
sorted(list_of_schools)
# Out:
# ['A.N. Pritzker School',
#  'ASPIRA Business and Finance',
#  'ASPIRA Charter School - Early College High School',
#  'ASPIRA Charter School - Haugan Middle School',
#  'Abraham Lincoln Elementary School',
#  'Academy for Global Citizenship Charter School',
#  'Acero Charter Schools - Bartolomé de las Casas',
#  'Acero Charter Schools - Brighton Park',
#  'Acero Charter Schools - Carlos Fuentes',
#  'Acero Charter Schools - Esmeralda Santiago',
#  'Acero Charter Schools - Jovita Idar',
#  'Acero Charter Schools - Major Hector P. Garcia MD',
#  'Acero Charter Schools - Octavio Paz Campus',
#  'Acero Charter Schools - Officer Donald J. Marquez',
#  'Acero Charter Schools - PFC Omar E. Torres',
#  'Acero Charter Schools - Roberto Clemente',
#  'Acero Charter Schools - Rufino Tamayo',
#  'Acero Charter Schools - SPC Daniel Zizumbo',
#  'Acero Charter Schools - Sandra Cisneros',
#  'Acero Charter Schools - Sor Juana Inés de la Cruz',
#  'Acero Charter Schools - Victoria Soto',
# ...

# %%
#partition data to creat df with only high school data
high_school_data1 = school_data1.loc[(school_data1['Primary_Category']== "HS")]
high_school_data1
# Out:
#      School_ID              Short_Name  \
# 2       609734                 TAFT HS
# 13      610386  PEACE AND EDUCATION HS
# 16      400113  CICS - CHICAGOQUEST HS
# 21      610391             LINDBLOM HS
# 23      400141           YCCS - TRUMAN
# ..         ...                     ...
# 640     400053       NOBLE - GOLDER HS
# 641     400156       NOBLE - BUTLER HS
# 642     400098       NOBLE - MUCHIN HS
# 644     610323                BOWEN HS
# 646     609739           WASHINGTON HS
#
#                                      Long_Name           School_Type  \
# 2              William Howard Taft High School          Neighborhood
# 13              Peace & Education Coalition HS       Citywide-Option
# 16                   CICS - ChicagoQuest North               Charter
# 21   Robert Lindblom Math & Science Academy HS  Selective enrollment
# 23               YCCS-Truman Middle College HS               Charter
# ..                                         ...                   ...
# ...

# %%
#partition data to creat df with only middle school data
middle_school_data1 = school_data1.loc[(school_data1['Primary_Category']== "MS")]
middle_school_data1
# Out:
#      School_ID       Short_Name  \
# 3       610588       RICHARDSON
# 120     610532        HERNANDEZ
# 215     610212      ALBANY PARK
# 223     610051        NORTHWEST
# 379     400017  ASPIRA - HAUGAN
# 455     610215           MADERO
# 611     610319        EVERGREEN
# 651     610559   SHIELDS MIDDLE
#
#                                              Long_Name   School_Type  \
# 3                   Robert J. Richardson Middle School  Neighborhood
# 120  Irene C. Hernandez Middle School for the Advan...  Neighborhood
# 215                  Albany Park Multicultural Academy  Neighborhood
# 223                            Northwest Middle School  Neighborhood
# 379       ASPIRA Charter School - Haugan Middle School       Charter
# 455                   Francisco I Madero Middle School  Neighborhood
# 611                    Evergreen Academy Middle School  Neighborhood
# 651                        James Shields Middle School  Neighborhood
#
# ...

# %%
#partition data to creat df with only elementary school data
Ele_school_data1 = school_data1.loc[(school_data1['Primary_Category']== "ES")]
Ele_school_data1
# Out:
#      School_ID      Short_Name                                 Long_Name  \
# 0       609869        LANGFORD        Anna R. Langford Community Academy
# 1       610225        WHISTLER           John Whistler Elementary School
# 4       609894           DRAKE            John B Drake Elementary School
# 5       610197         TALCOTT          Mancel Talcott Elementary School
# 6       610052            MANN             Horace Mann Elementary School
# ..         ...             ...                                       ...
# 648     610530  SOUTH SHORE ES             South Shore Fine Arts Academy
# 649     610193    NEW SULLIVAN  William K New Sullivan Elementary School
# 650     610200         THORP J           James N Thorp Elementary School
# 652     609978           SMITH           Wendell Smith Elementary School
# 653     610139         PULLMAN        George M Pullman Elementary School
#
#       School_Type Primary_Category                   Address     City  \
# ...

# %%
grouped_hs = high_school_data1.groupby("School_Type")
grouped_hs.count()
# Out:
#                       School_ID  Short_Name  Long_Name  Primary_Category  \
# School_Type
# Career academy                4           4          4                 4
# Charter                      65          65         65                65
# Citywide-Option              18          18         18                18
# Contract                      2           2          2                 2
# Magnet                        7           7          7                 7
# Military academy              6           6          6                 6
# Neighborhood                 46          46         46                46
# Selective enrollment         11          11         11                11
# Small                        13          13         13                13
# Special Education             4           4          4                 4
#
#                       Address  City  State  Zip  Phone  Fax  ...  \
# School_Type                                                  ...
# ...
